# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as  plt
import datetime
from dateutil.relativedelta import relativedelta
from datetime import date
import math

# %%
df=pd.read_csv("covid19_tweets.csv")

# %%
df
# Out:
#                            user_name         user_location  \
# 0                             ᏉᎥ☻լꂅϮ            astroworld
# 1                      Tom Basile 🇺🇸          New York, NY
# 2                    Time4fisticuffs      Pewee Valley, KY
# 3                        ethel mertz  Stuck in the Middle
# 4                           DIPR-J&K     Jammu and Kashmir
# ...                              ...                   ...
# 166651                         LynnZ                   NaN
# 166652  Public Health is the Economy         Sarasota, FL
# 166653           Farheen Qurashi, MD         Baltimore, MD
# 166654                  Alf O'Kenney          Montréal, QC
# 166655         J Michael 🇺🇸🏋🏼🏃🏼‍♂️🏝🚔           Connecticut
#
#                                          user_description  \
# 0       wednesday addams as a disney princess keepin i...
# 1       Husband, Father, Columnist & Commentator. Auth...
# 2       #Christian #Catholic #Conservative #Reagan #Re...
# ...

# %%
df.shape
# Out:
# (166656, 13)

# %%
df["Total_Tweets"]=df["user_name"].map(df["user_name"].value_counts())
df
# Out:
#                            user_name         user_location  \
# 0                             ᏉᎥ☻լꂅϮ            astroworld
# 1                      Tom Basile 🇺🇸          New York, NY
# 2                    Time4fisticuffs      Pewee Valley, KY
# 3                        ethel mertz  Stuck in the Middle
# 4                           DIPR-J&K     Jammu and Kashmir
# ...                              ...                   ...
# 166651                         LynnZ                   NaN
# 166652  Public Health is the Economy         Sarasota, FL
# 166653           Farheen Qurashi, MD         Baltimore, MD
# 166654                  Alf O'Kenney          Montréal, QC
# 166655         J Michael 🇺🇸🏋🏼🏃🏼‍♂️🏝🚔           Connecticut
#
#                                          user_description  \
# 0       wednesday addams as a disney princess keepin i...
# 1       Husband, Father, Columnist & Commentator. Auth...
# 2       #Christian #Catholic #Conservative #Reagan #Re...
# ...

# %%
df["date"]=pd.to_datetime(df["date"])
Tdays=math.ceil((df.iloc[df.shape[0]-1]["date"]-df.iloc[0]["date"]) / np.timedelta64(1,'D'))
Tdays
# Out:
# 28

# %%
df["Tweets per day"]=df["Total_Tweets"]/Tdays
df
# Out:
#                            user_name         user_location  \
# 0                             ᏉᎥ☻լꂅϮ            astroworld
# 1                      Tom Basile 🇺🇸          New York, NY
# 2                    Time4fisticuffs      Pewee Valley, KY
# 3                        ethel mertz  Stuck in the Middle
# 4                           DIPR-J&K     Jammu and Kashmir
# ...                              ...                   ...
# 166651                         LynnZ                   NaN
# 166652  Public Health is the Economy         Sarasota, FL
# 166653           Farheen Qurashi, MD         Baltimore, MD
# 166654                  Alf O'Kenney          Montréal, QC
# 166655         J Michael 🇺🇸🏋🏼🏃🏼‍♂️🏝🚔           Connecticut
#
#                                          user_description  \
# 0       wednesday addams as a disney princess keepin i...
# 1       Husband, Father, Columnist & Commentator. Auth...
# 2       #Christian #Catholic #Conservative #Reagan #Re...
# ...

# %%
Activecondition=[
    (df["Tweets per day"]<=0.1),
    (df["Tweets per day"]>0.1) & (df["Tweets per day"]<=0.7),
    (df["Tweets per day"]>0.7) & (df["Tweets per day"]<=2),
    (df["Tweets per day"]>2) & (df["Tweets per day"]<=5),
    (df["Tweets per day"]>5)
]
Activity=["Poor Active","Less Active","Moderate","Highly Active","Extremely Active"]
df["Activity Level"]=np.select(Activecondition,Activity)
df
# Out:
#                            user_name         user_location  \
# 0                             ᏉᎥ☻լꂅϮ            astroworld
# 1                      Tom Basile 🇺🇸          New York, NY
# 2                    Time4fisticuffs      Pewee Valley, KY
# 3                        ethel mertz  Stuck in the Middle
# 4                           DIPR-J&K     Jammu and Kashmir
# ...                              ...                   ...
# 166651                         LynnZ                   NaN
# 166652  Public Health is the Economy         Sarasota, FL
# 166653           Farheen Qurashi, MD         Baltimore, MD
# 166654                  Alf O'Kenney          Montréal, QC
# 166655         J Michael 🇺🇸🏋🏼🏃🏼‍♂️🏝🚔           Connecticut
#
#                                          user_description  \
# 0       wednesday addams as a disney princess keepin i...
# 1       Husband, Father, Columnist & Commentator. Auth...
# 2       #Christian #Catholic #Conservative #Reagan #Re...
# ...

# %%
df.to_csv('New_Covid19.csv')
